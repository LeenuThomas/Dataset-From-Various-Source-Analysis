# %%
import pandas as pd
import seaborn as sn
import matplotlib as plt

# %%
dfDibetic = pd.read_csv(r"C:\Users\ABRAHAM\Downloads\archive (14)\diabetes.csv")

# %%
dfDibetic.sample(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 102            0      125             96              0        0  22.5
# 1              1       85             66             29        0  26.6
# 404            5      168             64              0        0  32.9
# 633            1      128             82             17      183  27.5
# 601            6       96              0              0        0  23.7
# 239            0      104             76              0        0  18.4
# 398            3       82             70              0        0  21.1
# 381            0      105             68             22        0  20.0
# 408            8      197             74              0        0  25.9
# 637            2       94             76             18       66  31.6
#
#      DiabetesPedigreeFunction  Age  Outcome
# 102                     0.262   21        0
# 1                       0.351   31        0
# 404                     0.135   41        1
# ...

# %%
sn.scatterplot(dfDibetic['Glucose'],dfDibetic['BloodPressure'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Glucose', ylabel='BloodPressure'>

# %%
plt.figure()
sn.countplot(dfDibetic['Glucose'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 plt.figure()
#       2 sn.countplot(dfDibetic['Glucose'])
#
# TypeError: 'module' object is not callable

# %%
sn.scatterplot(dfDibetic['Glucose'],dfDibetic['BloodPressure'], hue = dfDibetic['Outcome'],style = dfDibetic['Age'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Glucose', ylabel='BloodPressure'>

# %%
df_filtered = dfDibetic.loc[(dfDibetic['Glucose'] == 120)| (dfDibetic['BloodPressure'] == 140)]

# %%
df_filtered.size
# Out:
# 99

# %%
plt.plot(df_filtered.Glucose, d)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 plt.plot(df_filtered)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\_api\__init__.py:222, in caching_module_getattr.<locals>.__getattr__(name)
#     220 if name in props:
#     221     return props[name].__get__(instance)
# --> 222 raise AttributeError(
#     223     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'plot'
